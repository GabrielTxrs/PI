# %% [markdown]
# # Example Jupyter Notebook
#
# This notebook serves as an example for the Python project.
#
# ## Introduction
# In this notebook, we will explore the functionalities of our Python project.

# %%
import sys
# !{sys.executable} -m pip install -r ../requirements.txt
import os
import numpy as np
import matplotlib.pyplot as plt
import skimage.io as io
from pdf2image import convert_from_path

# %%
paginas_do_pdf = convert_from_path('data/prova.pdf')
paginas_do_pdf[0].save('data/prova.jpg')
imagem = io.imread('data/prova.jpg')
print(imagem.shape)
plt.imshow(imagem)
# Out:
# (1473, 4862, 3)

# %%
os.system('tesseract data/prova.jpg output/output')

with open('output/output.txt', 'r') as file:
    text = file.read()

print(text)
# Out:
# Tesseract Open Source OCR Engine v4.1.1 with Leptonica
# ...
# Estimating resolution as 1040
# Questao 2 (4 pontos)
#
# Escreva uma fun¢déo para decidir se num tabuleiro de jogo da velha ha um vencedor e, caso exista,
# qual 6 o simbolo associado a ele.
#
# Sua func4o deve verificar as seguintes situagdes anémalas:
#
# 1, Ocorréncia de mais de um vencedor
# 2. Ocorréncia de mais de dois tipos de simbolos associados aos jogadores

# %%
import cv2

# Carrega a imagem
img = cv2.imread('data/prova.jpg', cv2.IMREAD_GRAYSCALE)

# Define os tamanhos das janelas
window_sizes = [(3, 3), (7, 7)]  # Exemplo com janelas 3x3 e 7x7

# Aplica a equalização local do histograma para cada tamanho de janela
for window_size in window_sizes:
    # Cria uma imagem vazia para armazenar o resultado
    result = np.zeros_like(img)
    
    # Percorre a imagem em blocos
    for i in range(0, img.shape[0], window_size[0]):
        for j in range(0, img.shape[1], window_size[1]):
            # Extrai o bloco da imagem
            block = img[i:i+window_size[0], j:j+window_size[1]]
            
            # Aplica a equalização do histograma no bloco
            equ = cv2.equalizeHist(block)
            
            # Insere o bloco equalizado na imagem de resultado
            result[i:i+window_size[0], j:j+window_size[1]] = equ
    
    # Salva a imagem resultante
    cv2.imwrite(f'prova_local_eq_{window_size[0]}x{window_size[1]}.jpg', result)

# %%
os.system('tesseract data/prova_local_eq_3x3.jpg output/equalizacao_3x3')
os.system('tesseract data/prova_local_eq_7x7.jpg output/equalizacao_7x7')
# Out:
# Tesseract Open Source OCR Engine v4.1.1 with Leptonica
# ...
# Estimating resolution as 366
# Tesseract Open Source OCR Engine v4.1.1 with Leptonica
# ...
# Estimating resolution as 585
# Detected 1827 diacritics
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# —rTs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kr is
# =
# TI 4, Th
#
# ees
#
# ni my
# hin” au
# a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
